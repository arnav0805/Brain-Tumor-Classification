# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalMaxPooling2D,GlobalAveragePooling2D, Dropout, Dense, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
from tqdm import tqdm

# %%
from warnings import filterwarnings
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
X_train = []
y_train = []
labels = ['glioma_tumor','no_tumor','meningioma_tumor','pituitary_tumor']


image_size = 224
for i in labels:
    folderPath = os.path.join('../input/brain-tumor-classification-mri/Training',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)

for i in labels:
    folderPath = os.path.join('../input/brain-tumor-classification-mri/Testing',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        y_train.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 826/826 [00:02<00:00, 358.88it/s]
# 100%|██████████| 395/395 [00:00<00:00, 420.06it/s]
# 100%|██████████| 822/822 [00:02<00:00, 372.63it/s]
# 100%|██████████| 827/827 [00:02<00:00, 373.71it/s]
# 100%|██████████| 100/100 [00:00<00:00, 355.29it/s]
# 100%|██████████| 105/105 [00:00<00:00, 574.39it/s]
# 100%|██████████| 115/115 [00:00<00:00, 465.04it/s]
# 100%|██████████| 74/74 [00:00<00:00, 232.92it/s]

# %%
X_train, y_train = shuffle(X_train,y_train, random_state=101)
X_train,X_test,y_train,y_test = train_test_split(X_train,y_train, test_size=0.1,random_state=101)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)

y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
# Load the EfficientNetB0 model pretrained on ImageNet without the top layers
efficientnetB0 = tf.keras.applications.EfficientNetB0(weights='imagenet',
                                                      include_top=False,
                                                      input_shape=(image_size, image_size, 3))


# Build the custom model on top of the EfficientNetB0 base
model = efficientnetB0.output
model = tf.keras.layers.GlobalAveragePooling2D()(model)
model = tf.keras.layers.Dense(1024,activation='relu')(model)
model = tf.keras.layers.Dropout(rate=0.4)(model)
model = tf.keras.layers.Dense(4,activation='softmax')(model)
model = tf.keras.models.Model(inputs=efficientnetB0.input, outputs = model)
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()

# %%
# Tensorboard callback for logging training metrics
tensorboard = TensorBoard(log_dir='logs')

# Modelcheckpoint callback to save the best model 
checkpoint = ModelCheckpoint("efficientnetB0.keras", monitor="val_accuracy",
                             save_best_only=True, verbose=1)

# ReduceLROnPlateau callback to reduce learning rate if validation accuracy plateaus
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.1, patience=2, 
                              min_delta=0.0001, verbose=1)

# %%
history = model.fit(X_train,y_train,validation_split = 0.1, epochs = 21, verbose = 1,
                    batch_size = 32, callbacks=[tensorboard,checkpoint,reduce_lr])
# Out:
# Epoch 1/21
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - accuracy: 0.7564 - loss: 0.6083
# Epoch 1: val_accuracy improved from -inf to 0.65306, saving model to efficientnetB0.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 124s 700ms/step - accuracy: 0.7574 - loss: 0.6063 - val_accuracy: 0.6531 - val_loss: 1.4280 - learning_rate: 0.0010
# Epoch 2/21
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9199 - loss: 0.2283
# Epoch 2: val_accuracy improved from 0.65306 to 0.74830, saving model to efficientnetB0.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - accuracy: 0.9200 - loss: 0.2278 - val_accuracy: 0.7483 - val_loss: 1.0071 - learning_rate: 0.0010
# Epoch 3/21
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9645 - loss: 0.1216
# Epoch 3: val_accuracy did not improve from 0.74830
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 10s 115ms/step - accuracy: 0.9644 - loss: 0.1219 - val_accuracy: 0.7381 - val_loss: 0.9001 - learning_rate: 0.0010
# Epoch 4/21
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9658 - loss: 0.1022
# Epoch 4: val_accuracy improved from 0.74830 to 0.83333, saving model to efficientnetB0.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - accuracy: 0.9658 - loss: 0.1021 - val_accuracy: 0.8333 - val_loss: 0.5370 - learning_rate: 0.0010
# Epoch 5/21
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9752 - loss: 0.0788
# Epoch 5: val_accuracy did not improve from 0.83333
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 10s 115ms/step - accuracy: 0.9752 - loss: 0.0788 - val_accuracy: 0.7721 - val_loss: 0.9471 - learning_rate: 0.0010
# Epoch 6/21
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9810 - loss: 0.0675
# Epoch 6: val_accuracy did not improve from 0.83333
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 10s 115ms/step - accuracy: 0.9810 - loss: 0.0676 - val_accuracy: 0.7857 - val_loss: 0.7685 - learning_rate: 0.0010
# Epoch 7/21
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9803 - loss: 0.0686
# Epoch 7: val_accuracy improved from 0.83333 to 0.92857, saving model to efficientnetB0.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - accuracy: 0.9804 - loss: 0.0684 - val_accuracy: 0.9286 - val_loss: 0.2776 - learning_rate: 1.0000e-04
# Epoch 8/21
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9907 - loss: 0.0334
# Epoch 8: val_accuracy improved from 0.92857 to 0.95238, saving model to efficientnetB0.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - accuracy: 0.9907 - loss: 0.0333 - val_accuracy: 0.9524 - val_loss: 0.2038 - learning_rate: 1.0000e-04
# Epoch 9/21
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9953 - loss: 0.0166
# Epoch 9: val_accuracy improved from 0.95238 to 0.95578, saving model to efficientnetB0.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - accuracy: 0.9954 - loss: 0.0165 - val_accuracy: 0.9558 - val_loss: 0.1919 - learning_rate: 1.0000e-04
# Epoch 10/21
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9958 - loss: 0.0159
# Epoch 10: val_accuracy improved from 0.95578 to 0.96259, saving model to efficientnetB0.keras
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - accuracy: 0.9958 - loss: 0.0158 - val_accuracy: 0.9626 - val_loss: 0.1915 - learning_rate: 1.0000e-04
# Epoch 11/21
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9973 - loss: 0.0105
# Epoch 11: val_accuracy did not improve from 0.96259
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 10s 115ms/step - accuracy: 0.9973 - loss: 0.0104 - val_accuracy: 0.9524 - val_loss: 0.1967 - learning_rate: 1.0000e-04
# Epoch 12/21
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9965 - loss: 0.0092
# Epoch 12: val_accuracy did not improve from 0.96259
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 10s 115ms/step - accuracy: 0.9966 - loss: 0.0092 - val_accuracy: 0.9558 - val_loss: 0.2008 - learning_rate: 1.0000e-04
# Epoch 13/21
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9983 - loss: 0.0058
# Epoch 13: val_accuracy did not improve from 0.96259
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 10s 116ms/step - accuracy: 0.9983 - loss: 0.0058 - val_accuracy: 0.9524 - val_loss: 0.2021 - learning_rate: 1.0000e-05
# Epoch 14/21
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9988 - loss: 0.0039
# Epoch 14: val_accuracy did not improve from 0.96259
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 10s 115ms/step - accuracy: 0.9988 - loss: 0.0039 - val_accuracy: 0.9558 - val_loss: 0.2026 - learning_rate: 1.0000e-05
# Epoch 15/21
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9980 - loss: 0.0135
# Epoch 15: val_accuracy did not improve from 0.96259
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 10s 115ms/step - accuracy: 0.9980 - loss: 0.0134 - val_accuracy: 0.9524 - val_loss: 0.2037 - learning_rate: 1.0000e-06
# Epoch 16/21
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9995 - loss: 0.0029
# Epoch 16: val_accuracy did not improve from 0.96259
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 10s 115ms/step - accuracy: 0.9995 - loss: 0.0029 - val_accuracy: 0.9524 - val_loss: 0.2038 - learning_rate: 1.0000e-06
# Epoch 17/21
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9959 - loss: 0.0073
# Epoch 17: val_accuracy did not improve from 0.96259
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 10s 115ms/step - accuracy: 0.9959 - loss: 0.0073 - val_accuracy: 0.9524 - val_loss: 0.2039 - learning_rate: 1.0000e-07
# Epoch 18/21
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9987 - loss: 0.0055
# Epoch 18: val_accuracy did not improve from 0.96259
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 10s 115ms/step - accuracy: 0.9986 - loss: 0.0055 - val_accuracy: 0.9524 - val_loss: 0.2039 - learning_rate: 1.0000e-07
# Epoch 19/21
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9957 - loss: 0.0077
# Epoch 19: val_accuracy did not improve from 0.96259
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 10s 115ms/step - accuracy: 0.9957 - loss: 0.0077 - val_accuracy: 0.9524 - val_loss: 0.2036 - learning_rate: 1.0000e-08
# Epoch 20/21
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9990 - loss: 0.0033
# Epoch 20: val_accuracy did not improve from 0.96259
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 10s 116ms/step - accuracy: 0.9990 - loss: 0.0034 - val_accuracy: 0.9524 - val_loss: 0.2035 - learning_rate: 1.0000e-08
# Epoch 21/21
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9970 - loss: 0.0075
# Epoch 21: val_accuracy did not improve from 0.96259
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 10s 115ms/step - accuracy: 0.9970 - loss: 0.0075 - val_accuracy: 0.9524 - val_loss: 0.2031 - learning_rate: 1.0000e-09

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plotting training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
y_true_test = np.argmax(y_test, axis=1)
y_pred_test = np.argmax(model.predict(X_test), axis=1) 

heatmap = sns.heatmap(confusion_matrix(y_true_test,y_pred_test), annot=True, fmt='d', cmap='Blues_r',
                      xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 617ms/step

# %%
print(classification_report(y_true_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98        93
#            1       0.98      1.00      0.99        51
#            2       0.98      0.97      0.97        96
#            3       0.98      1.00      0.99        87
#
#     accuracy                           0.98       327
#    macro avg       0.98      0.98      0.98       327
# weighted avg       0.98      0.98      0.98       327
